# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
d=pd.read_csv('/content/dailyActivity_merged.csv')

# %%
print(d.isnull)
d1=d.fillna(0)
# Out:
# <bound method DataFrame.isnull of              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
# ...

# %%
import matplotlib.pyplot as pt

# %%
x1=d1['TotalSteps']
y=d1['Id']
pt.plot(x1,y)

# %%
x2=d1['ActivityDate']
y=d1['Id']
pt.plot(x2,y)

# %%
x3=d1['TotalDistance']
y=d1['Id']
pt.plot(x3,y)

# %%
x4=d1['TrackerDistance']
y=d1['Id']
pt.plot(x4,y)

# %%
x5=d1['LoggedActivitiesDistance']
y=d1['Id']
pt.plot(x5,y)

# %%
x6=d1['VeryActiveDistance']
y=d1['Id']
pt.plot(x6,y)

# %%
x7=d1['ModeratelyActiveDistance']
y=d1['Id']
pt.plot(x7,y)

# %%
x8=d1['LightActiveDistance']
y=d1['Id']
pt.plot(x8,y)

# %%
x9=d1['SedentaryActiveDistance']
y=d1['Id']
pt.plot(x9,y)

# %%
x10=d1['VeryActiveMinutes']
y=d1['Id']
pt.plot(x10,y)

# %%
x11=d1['FairlyActiveMinutes']
y=d1['Id']
pt.plot(x11,y)

# %%
x12=d1['LightlyActiveMinutes']
y=d1['Id']
pt.plot(x12,y)

# %%
x13=d1['SedentaryMinutes']
y=d1['Id']
pt.plot(x13,y)

# %%
x14=d1['Calories']
y=d1['Id']
pt.plot(x14,y)
